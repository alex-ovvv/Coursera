# %%
import pandas as pd

import numpy as np

frame = pd.read_csv("sample_1.tsv", sep = "\t", header=0, encoding="windows-1251")

# %%
frame
# Out:
#             ID Дата.изменения.статуса                  Статус         Автор  \
# 0     286673.0    2088-04-03 20:03:13                   Новый   token_52970
# 1     286673.0    2088-04-03 20:03:14                   Новый   token_52970
# 2     286673.0    2088-04-03 20:03:16                   Новый   token_52970
# 3     286673.0    2088-04-03 20:12:40                Инцидент      token_NA
# 4     286673.0    2088-04-03 21:48:07                Инцидент   token_52970
# 5     286673.0    2088-04-03 22:10:40  Ожидание ответа автора  token_111417
# 6     286673.0    2088-04-03 22:10:41  Ожидание ответа автора      token_NA
# 7     286673.0    2088-04-03 22:13:12                Инцидент      token_NA
# 8     286673.0    2088-04-03 22:13:13                Инцидент   token_52970
# 9     286673.0    2088-04-03 22:13:13                Инцидент   token_52970
# 10    286673.0    2088-04-03 22:13:15                Инцидент   token_52970
# ...

# %%
frame.rename(index=str, columns={"Тип.обращения": "Type"}, inplace=True)

# %%
frame.columns
# Out:
# Index(['ID', 'Дата.изменения.статуса', 'Статус', 'Автор', 'Пользователь',
#        'Категория.автора', 'Контент', 'Type', 'Хост', 'Подписчики', 'Тема',
#        'Локация', 'Тональность', 'Тип'],
#       dtype='object')

# %%
frame.columns
# Out:
# Index([], dtype='object')

# %%
frame.iloc[np.where(frame["Type"]=="Личное сообщение")]
# Out:
#             ID Дата.изменения.статуса     Статус         Автор  Пользователь  \
# 0     286673.0    2088-04-03 20:03:13      Новый   token_52970  token_111453
# 1     286673.0    2088-04-03 20:03:14      Новый   token_52970  token_111453
# 2     286673.0    2088-04-03 20:03:16      Новый   token_52970  token_111453
# 4     286673.0    2088-04-03 21:48:07   Инцидент   token_52970      token_NA
# 8     286673.0    2088-04-03 22:13:13   Инцидент   token_52970      token_NA
# 9     286673.0    2088-04-03 22:13:13   Инцидент   token_52970      token_NA
# 10    286673.0    2088-04-03 22:13:15   Инцидент   token_52970      token_NA
# 11    286673.0    2088-04-03 22:13:17   Инцидент   token_52970      token_NA
# 14    289802.0    2088-04-04 23:13:49      Новый   token_43229  token_111453
# 15    289802.0    2088-04-04 23:18:49      Новый   token_43229  token_111453
# 20    289802.0    2088-04-05 04:13:54   Инцидент   token_43229      token_NA
# ...

# %%
#frame.iloc[np.where(frame["Пользователь"]=="token_111453")]
frame.columns
# Out:
# Index([], dtype='object')

# %%
filtered_frame = frame[frame['Контент'].notnull()]

# %%
filtered_frame
# Out:
#             ID Дата.изменения.статуса                  Статус         Автор  \
# 0     286673.0    2088-04-03 20:03:13                   Новый   token_52970
# 1     286673.0    2088-04-03 20:03:14                   Новый   token_52970
# 2     286673.0    2088-04-03 20:03:16                   Новый   token_52970
# 4     286673.0    2088-04-03 21:48:07                Инцидент   token_52970
# 5     286673.0    2088-04-03 22:10:40  Ожидание ответа автора  token_111417
# 8     286673.0    2088-04-03 22:13:13                Инцидент   token_52970
# 9     286673.0    2088-04-03 22:13:13                Инцидент   token_52970
# 10    286673.0    2088-04-03 22:13:15                Инцидент   token_52970
# 11    286673.0    2088-04-03 22:13:17                Инцидент   token_52970
# 12    286673.0    2088-04-04 00:29:18                Закрытые  token_111417
# 14    289802.0    2088-04-04 23:13:49                   Новый   token_43229
# ...

# %%
import glob

#path ="sample_1.tsv" #use your path
allFiles = glob.glob("sample_1.tsv" + "sample_2.tsv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-0bbbc1f90950> in <module>()
#       8     df = pd.read_csv(file_,index_col=None, header=0)
#       9     list_.append(df)
# ---> 10 frame = pd.concat(list_)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     257
#     258         if len(objs) == 0:
# ...

# %%
import pandas as pd
import numpy as np

from tqdm import tqdm_notebook

import gensim.models

from gensim.models import word2vec
from gensim.models import Doc2Vec
from gensim.models.doc2vec import LabeledSentence, TaggedDocument
import logging

import math

import json

from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity
import math

from datetime import datetime

from keras.models import Model
from keras.layers import Input, Dense

from keras.layers import *
from keras.models import *

from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt

import hyperopt
from catboost import Pool, CatBoostClassifier, cv, CatboostIpythonWidget

from sklearn.linear_model import LogisticRegression

from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_error

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-69-7bb15f697729> in <module>()
#       4 from tqdm import tqdm_notebook
#       5
# ----> 6 import gensim.models
#       7
#       8 from gensim.models import word2vec
#
# ModuleNotFoundError: No module named 'gensim'
